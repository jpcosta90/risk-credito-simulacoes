# %%
import numpy as np
import random
import pandas as pd
import numpy_financial as npf

import os
import psycopg2
import psycopg2.extras as ext
import datetime

# %%
''''
chave_prob = {1 : 0.015,
             2:  0.010,
             3:  0.008,
             4:  0.006,
             5:  0.002,
             6:  0.0000}
'''''
chave_prob = {1 : 1.50,
              2:  1.20,
              3:  0.90,
              4:  0.80,
              5:  0.60,
              6:  0.40}   
    
chave_valr = {1 : 1.00,
             2:  1.50,
             3:  2.00,
             4:  3.00,
             5:  3.50,
             6:  4.00}

# %%
#[0.419, 0.156, 0.167, 0.146, 0.072, 0.041]
#[1/6, 1/6, 1/6, 1/6, 1/6, 1/6]

class cliente:
    def __init__(self, codigo):
        self.codigo = codigo
 #       self.inad = max(0.02 + np.random.normal(0., 0.005),0.003)
        self.porte = int(np.where(np.random.multinomial(1, [0.419, 0.156, 0.167, 0.146, 0.072, 0.041], size=1) == 1)[1][0] + 1)
        self.inad = max(0.06 + np.random.normal(0., 0.005),0.0003) * chave_prob[self.porte]
        self.mtlp = chave_valr[self.porte]

# %% [markdown]
# ## Simula base de clientes

# %%
clientes = []

for i in range(5000000):
    clientes.append(cliente(str(i).zfill(7)))

# %%
chave_mdld_rec = {1 : 1.000,
                  2:  0.800,
                  3:  0.600,
                  4:  0.400}

chave_atraso_rec = {1: 300,
                    2: 180,
                    3: 150,
                    4: 120}

chave_mdld_valor = {1 : 2.5,
                    2:  2.0,
                    3:  3.5,
                    4:  5.0}

chave_prazo =      {1 : 0,
                    2:  0,
                    3:  0,
                    4:  5}

chave_prt_inad =      {1 : 3.50,
                       2:  2.00,
                       3:  1.00,
                       4:  0.50}

# %%
import matplotlib.pyplot as plt 

plt.hist(np.random.lognormal(8., 0.4, size=100000))
# Out:
# (array([2.3186e+04, 5.2616e+04, 1.8794e+04, 4.2690e+03, 8.7300e+02,
#         1.9900e+02, 4.3000e+01, 1.6000e+01, 3.0000e+00, 1.0000e+00]),
#  array([  496.0931929 ,  2219.77143362,  3943.44967434,  5667.12791507,
#          7390.80615579,  9114.48439651, 10838.16263723, 12561.84087795,
#         14285.51911868, 16009.1973594 , 17732.87560012]),
#  <BarContainer object of 10 artists>)

# %%
#[0.147, 0.779, 0.050, 0.024]
#[1/4, 1/4, 1/4, 1/4]

class operacao:
    def __init__(self, contrato, ref,  mes, dia, choque = 0.0):
        self.ref = ref
        self.cliente = random.sample(clientes, 1)[0]
        self.modalidade = int(np.where(np.random.multinomial(1, [0.147, 0.747, 0.070, 0.036], size=1) == 1)[1][0] + 1)
        self.valor = (np.random.lognormal(8., 0.5, size=None)) * chave_mdld_valor[self.modalidade] * self.cliente.mtlp
        self.mtpl_inad = chave_prt_inad[self.modalidade]
        self.choque = choque
        self.p_inad = min(self.cliente.inad * self.mtpl_inad *(1 + self.choque) , 0.70)
        self.prazo = int(np.random.uniform(low=1, high=10, size=None)) * 6 * (1 + chave_prazo[self.modalidade])
        self.juros = 0.01
        self.mtpl_rec = chave_mdld_rec[self.modalidade]
        self.parcela = npf.pmt(self.juros, self.prazo, self.valor)
        self.multa = 0
        self.pagamento = 0
        self.contrato = contrato
        self.atraso = 0
        self.mes = mes
        self.dia = dia

# %% [markdown]
# ### Gerar Operações por dia e agregar na base com o mês

# %%
def contrata(mes, ctr_dia, ref, choque):
    
    operacoes = []

    for d in range(1, 31):
        q = np.random.poisson(lam=ctr_dia, size=None)
        
        for i in range(q):
            operacoes.append(operacao(str(mes).zfill(3) + str(d).zfill(2)+(str(i)).zfill(6), ref, mes, d, choque))
            
    return(operacoes)

# %% [markdown]
# ### Atualização do mês
# #### e inclusão de novas contratações

# %%
def atualiza_mes(anterior, ctr_dia=50, choque = 0.0):
    #print(len(anterior))
    atual = []

    for i in range(len(anterior)):

        atual.append(anterior[i])

        dia = 30 - anterior[i].dia
        
        #ajustar atraso para somar 30 dias se menor que 30 dia se não + 30
        
        p_atraso = np.random.binomial(size = None, n = 1, p = min(anterior[i].p_inad, 0.99999))
        
        if anterior[i].atraso < 30:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * dia
        else:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * 30
            
        if temp_atraso == 0:
            p = min(anterior[i].p_inad * (1  + choque), 0.70)
        elif temp_atraso < 30:
            p = 0.20 + 0.20 * (temp_atraso - 0)/30
        elif temp_atraso < 60:
            p = 0.40 + 0.10 * (temp_atraso - 30)/30
        elif temp_atraso < 90:    
            p = 0.50 + 0.05 * (temp_atraso - 60)/30
        elif temp_atraso < 120:
            p = 0.75 * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 150:
            p = 0.80 * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 180:
            p = 0.85  * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 270:
            p = 0.90
        elif temp_atraso < 300:
            p = 0.95 
        elif temp_atraso < 330:
            p = 0.975 
        elif temp_atraso < 360:
            p = 0.995 
        else:
            p = 1.000

        atual[i].cliente.inad = anterior[i].cliente.inad * (p/anterior[i].p_inad)
        atual[i].p_inad = p
        atual[i].prazo = anterior[i].prazo - 1
        atual[i].ref = anterior[i].ref + 1
        
        atual[i].valor = max((anterior[i].valor) * (1 + anterior[i].juros) + ((anterior[i].parcela - atual[i].multa) * (1 - p_atraso)), 0)  
        
        #if atual[i].modalidade == 4 and anterior[i].atraso > 90 and p_atraso == 0:
        if anterior[i].atraso > chave_atraso_rec[atual[i].modalidade] and p_atraso == 0:
                    atual[i].pagamento = atual[i].valor
                    atual[i].valor = 0
                    atual[i].prazo = 0
        else:
            atual[i].pagamento = (-anterior[i].parcela + anterior[i].multa) * (1 - p_atraso)
            
        atual[i].atraso = temp_atraso

        atual[i].multa = - (anterior[i].parcela * p_atraso * (1 + anterior[i].juros)) + (anterior[i].multa * p_atraso)
        
        
    atual.extend(contrata(anterior[i].mes + 1, ctr_dia, anterior[i].ref, choque = choque))
    
    return(atual)

        ## Incluir probabilidade de inadimplência em 1 mês ok
        ## atualizar dias de atraso ok
        ## utilizar probabilidades de recuperação e inadimplência do System Dynamics ok
        
        
        ## atualizar mes de referencia ok
        ## atualizar prazo ok
        ## atualizar liquidação ok
        ## exportar cada nova tabela ok
        ## criar loop ok
        ## atualizar probabilidades na base de clientes ok

# %% [markdown]
# ## Bases geradas

# %%
nmes = 240
mes_choque = [121, 144]
ichoque = 0.3
ctr_dia = 100

m = []
f = []

now = datetime.datetime.now()
print ("Início do processamento base 0 :", now.strftime("%Y-%m-%d %H:%M:%S"))
    
base0 = contrata(0, ctr_dia, 0, choque = 0.0)
linhas = len(base0)

conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
cur = conn.cursor(cursor_factory = ext.DictCursor)

for n in range(linhas):
    log = []
    sql = "INSERT INTO jpcosta.operacoes( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
    values = [base0[n].ref , base0[n].cliente.codigo, base0[n].cliente.porte, base0[n].contrato, base0[n].modalidade, base0[n].prazo, base0[n].valor, base0[n].mes, base0[n].dia, base0[n].p_inad, base0[n].cliente.inad, base0[n].atraso, base0[n].pagamento]
    cur.execute(sql, values)
    conn.commit()
    results = cur.fetchall()
cur.close()
conn.close()


now = datetime.datetime.now()

print ("Fim do processamento base 0    :", now.strftime("%Y-%m-%d %H:%M:%S"))

for i in range(nmes):
    
    if ((i >= mes_choque[0]) & (i <= mes_choque[1])):
        texto = 'choque de ' + str(ichoque)
        choque = ichoque
    else:
        texto = 'sem choque'
        choque = 0.0
        
    now = datetime.datetime.now()
    print ("Início do processamento base", str(i + 1), "(", texto, "):", now.strftime("%Y-%m-%d %H:%M:%S"))
    exec("base" + str(i+1) + " = atualiza_mes(" + "base" + str(i) + ", "+ str(ctr_dia) + ", choque = "+ str(choque) + ")",)
    exec("linhas = len(base" + str(i + 1) + ")")      

    conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
    cur = conn.cursor(cursor_factory = ext.DictCursor)
    exec("linhas = len(base" + str(i + 1) + ")")
    
    for n in range(linhas):
        exec("saldo = base" + str(i + 1) + "[n].valor")
        exec("dias = base" + str(i + 1) + "[n].atraso")
        exec("prazo = base" + str(i + 1) + "[n].prazo")
        if saldo < 1.0 and dias == 0 and prazo < 0:
            None
        else:
            sql = "INSERT INTO jpcosta.operacoes( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
            exec("values = [base"+ str(i+1) + "[n].ref " + ", base"+ str(i+1) + "[n].cliente.codigo" + ", base"+ str(i+1) + "[n].cliente.porte" + ", base"+ str(i+1) + "[n].contrato" + ", base"+ str(i+1) + "[n].modalidade" +  ", base"+ str(i+1) + "[n].prazo" + ", base"+ str(i+1) + "[n].valor" + ", base"+ str(i+1) + "[n].mes" +
                 ", base"+ str(i+1) + "[n].dia" + ", base"+ str(i+1) + "[n].p_inad" + ", base"+ str(i+1) + "[n].cliente.inad" + ", base"+ str(i+1) + "[n].atraso" + ", base"+ str(i+1) + "[n].pagamento]", globals(), locals())
            cur.execute(sql, values)
            conn.commit()
            results = cur.fetchall()
            
            m.append(i)
            exec("f.append(" + "base" + str(i+1) +"[n].p_inad)")
            
    cur.close()
    conn.close()
                
    now = datetime.datetime.now()
    print ("Fim do processamento base", str(i + 1), "   :", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Início do processamento base 0 : 2021-12-18 12:15:08
# Fim do processamento base 0    : 2021-12-18 12:15:18
# Início do processamento base 1 ( sem choque ): 2021-12-18 12:15:18
# Fim do processamento base 1    : 2021-12-18 12:15:39
# Início do processamento base 2 ( sem choque ): 2021-12-18 12:15:39
# Fim do processamento base 2    : 2021-12-18 12:16:10
# Início do processamento base 3 ( sem choque ): 2021-12-18 12:16:10
# Fim do processamento base 3    : 2021-12-18 12:16:54
# Início do processamento base 4 ( sem choque ): 2021-12-18 12:16:54
# Fim do processamento base 4    : 2021-12-18 12:17:48
# Início do processamento base 5 ( sem choque ): 2021-12-18 12:17:48
# Fim do processamento base 5    : 2021-12-18 12:18:50
# Início do processamento base 6 ( sem choque ): 2021-12-18 12:18:50
# Fim do processamento base 6    : 2021-12-18 12:20:02
# Início do processamento base 7 ( sem choque ): 2021-12-18 12:20:02
# Fim do processamento base 7    : 2021-12-18 12:21:23
# Início do processamento base 8 ( sem choque ): 2021-12-18 12:21:23
# Fim do processamento base 8    : 2021-12-18 12:22:55
# Início do processamento base 9 ( sem choque ): 2021-12-18 12:22:55
# Fim do processamento base 9    : 2021-12-18 12:24:37
# Início do processamento base 10 ( sem choque ): 2021-12-18 12:24:37
# Fim do processamento base 10    : 2021-12-18 12:26:27
# Início do processamento base 11 ( sem choque ): 2021-12-18 12:26:27
# Fim do processamento base 11    : 2021-12-18 12:28:23
# Início do processamento base 12 ( sem choque ): 2021-12-18 12:28:23
# Fim do processamento base 12    : 2021-12-18 12:30:29
# Início do processamento base 13 ( sem choque ): 2021-12-18 12:30:29
# Fim do processamento base 13    : 2021-12-18 12:32:44
# Início do processamento base 14 ( sem choque ): 2021-12-18 12:32:44
# Fim do processamento base 14    : 2021-12-18 12:35:05
# Início do processamento base 15 ( sem choque ): 2021-12-18 12:35:05
# Fim do processamento base 15    : 2021-12-18 12:37:36
# Início do processamento base 16 ( sem choque ): 2021-12-18 12:37:36
# Fim do processamento base 16    : 2021-12-18 12:40:14
# Início do processamento base 17 ( sem choque ): 2021-12-18 12:40:14
# Fim do processamento base 17    : 2021-12-18 12:43:01
# Início do processamento base 18 ( sem choque ): 2021-12-18 12:43:01
# Fim do processamento base 18    : 2021-12-18 12:45:55
# Início do processamento base 19 ( sem choque ): 2021-12-18 12:45:55
# Fim do processamento base 19    : 2021-12-18 12:49:00
# Início do processamento base 20 ( sem choque ): 2021-12-18 12:49:00
# Fim do processamento base 20    : 2021-12-18 12:52:12
# Início do processamento base 219 ( sem choque ): 2021-12-20 04:50:08
# Fim do processamento base 219    : 2021-12-20 05:10:27
# Início do processamento base 220 ( sem choque ): 2021-12-20 05:10:27
# Fim do processamento base 220    : 2021-12-20 05:30:48
# Início do processamento base 221 ( sem choque ): 2021-12-20 05:30:48
# Fim do processamento base 221    : 2021-12-20 05:50:38
# Início do processamento base 222 ( sem choque ): 2021-12-20 05:50:38
# Fim do processamento base 222    : 2021-12-20 06:10:40
# Início do processamento base 223 ( sem choque ): 2021-12-20 06:10:40
# Fim do processamento base 223    : 2021-12-20 06:30:30
# Início do processamento base 224 ( sem choque ): 2021-12-20 06:30:30
# Fim do processamento base 224    : 2021-12-20 06:50:36
# Início do processamento base 225 ( sem choque ): 2021-12-20 06:50:36
# Fim do processamento base 225    : 2021-12-20 07:10:49
# Início do processamento base 226 ( sem choque ): 2021-12-20 07:10:49
# Fim do processamento base 226    : 2021-12-20 07:31:19
# Início do processamento base 227 ( sem choque ): 2021-12-20 07:31:19
# Fim do processamento base 227    : 2021-12-20 07:51:50
# Início do processamento base 228 ( sem choque ): 2021-12-20 07:51:50
# Fim do processamento base 228    : 2021-12-20 08:12:26
# Início do processamento base 229 ( sem choque ): 2021-12-20 08:12:26
# Fim do processamento base 229    : 2021-12-20 08:33:08
# Início do processamento base 230 ( sem choque ): 2021-12-20 08:33:09
# Fim do processamento base 230    : 2021-12-20 08:54:19
# Início do processamento base 231 ( sem choque ): 2021-12-20 08:54:19
# Fim do processamento base 231    : 2021-12-20 09:15:13
# Início do processamento base 232 ( sem choque ): 2021-12-20 09:15:13
# Fim do processamento base 232    : 2021-12-20 09:36:17
# Início do processamento base 233 ( sem choque ): 2021-12-20 09:36:17
# Fim do processamento base 233    : 2021-12-20 09:57:41
# Início do processamento base 234 ( sem choque ): 2021-12-20 09:57:41
# Fim do processamento base 234    : 2021-12-20 10:19:17
# Início do processamento base 235 ( sem choque ): 2021-12-20 10:19:17
# Fim do processamento base 235    : 2021-12-20 10:40:47
# Início do processamento base 236 ( sem choque ): 2021-12-20 10:40:47
# Fim do processamento base 236    : 2021-12-20 11:02:34
# Início do processamento base 237 ( sem choque ): 2021-12-20 11:02:34
# Fim do processamento base 237    : 2021-12-20 11:24:19
# Início do processamento base 238 ( sem choque ): 2021-12-20 11:24:19
# Fim do processamento base 238    : 2021-12-20 11:46:04
# Início do processamento base 239 ( sem choque ): 2021-12-20 11:46:04
# Fim do processamento base 239    : 2021-12-20 12:08:05
# Início do processamento base 240 ( sem choque ): 2021-12-20 12:08:05
# Fim do processamento base 240    : 2021-12-20 12:30:03

# %%
cur.close()
conn.close()

# %% [raw]
# conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=jpcosta password=12345678")
# cur = conn.cursor(cursor_factory = ext.DictCursor)
#
# sql = "DELETE FROM jpcosta.operacoes WHERE ref > -1;"
# cur.execute(sql)
#
# cur.execute(sql)
# conn.commit()
# cur.close()
# conn.close()
