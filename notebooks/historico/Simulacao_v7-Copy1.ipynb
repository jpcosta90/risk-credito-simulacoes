# %%
import numpy as np
import random
import pandas as pd
import numpy_financial as npf

import os
import psycopg2
import psycopg2.extras as ext
import datetime

# %%
''''
chave_prob = {1 : 0.015,
             2:  0.010,
             3:  0.008,
             4:  0.006,
             5:  0.002,
             6:  0.0000}
'''''
chave_prob = {1 : 1.50,
              2:  1.20,
              3:  0.90,
              4:  0.80,
              5:  0.60,
              6:  0.40}   
    
chave_valr = {1 : 1.00,
             2:  1.50,
             3:  2.00,
             4:  3.00,
             5:  3.50,
             6:  4.00}

# %%
#[0.419, 0.156, 0.167, 0.146, 0.072, 0.041]
#[1/6, 1/6, 1/6, 1/6, 1/6, 1/6]

class cliente:
    def __init__(self, codigo):
        self.codigo = codigo
 #       self.inad = max(0.02 + np.random.normal(0., 0.005),0.003)
        self.porte = int(np.where(np.random.multinomial(1, [0.419, 0.156, 0.167, 0.146, 0.072, 0.041], size=1) == 1)[1][0] + 1)
        self.inad = max(0.06 + np.random.normal(0., 0.005),0.0003) * chave_prob[self.porte]
        self.mtlp = chave_valr[self.porte]

# %% [markdown]
# ## Simula base de clientes

# %%
clientes = []

for i in range(5000000):
    clientes.append(cliente(str(i).zfill(7)))

# %%
chave_mdld_rec = {1 : 1.000,
                  2:  0.800,
                  3:  0.600,
                  4:  0.400}

chave_atraso_rec = {1: 300,
                    2: 180,
                    3: 150,
                    4: 120}

chave_mdld_valor = {1 : 2.5,
                    2:  2.0,
                    3:  3.5,
                    4:  5.0}

chave_prazo =      {1 : 0,
                    2:  0,
                    3:  0,
                    4:  5}

chave_prt_inad =      {1 : 3.50,
                       2:  2.00,
                       3:  1.00,
                       4:  0.50}

# %%
import matplotlib.pyplot as plt 

plt.hist(np.random.lognormal(8., 0.4, size=100000))
# Out:
# (array([2.4990e+04, 5.1511e+04, 1.8133e+04, 4.1990e+03, 9.1300e+02,
#         1.9500e+02, 4.5000e+01, 1.1000e+01, 2.0000e+00, 1.0000e+00]),
#  array([  565.83019403,  2273.74948242,  3981.66877081,  5689.58805919,
#          7397.50734758,  9105.42663596, 10813.34592435, 12521.26521274,
#         14229.18450112, 15937.10378951, 17645.02307789]),
#  <BarContainer object of 10 artists>)

# %%
#[0.147, 0.779, 0.050, 0.024]
#[1/4, 1/4, 1/4, 1/4]

class operacao:
    def __init__(self, contrato, ref,  mes, dia, choque = 0.0):
        self.ref = ref
        self.cliente = random.sample(clientes, 1)[0]
        self.modalidade = int(np.where(np.random.multinomial(1, [0.147, 0.747, 0.070, 0.036], size=1) == 1)[1][0] + 1)
        self.valor = (np.random.lognormal(8., 0.5, size=None)) * chave_mdld_valor[self.modalidade] * self.cliente.mtlp
        self.mtpl_inad = chave_prt_inad[self.modalidade]
        self.choque = choque
        self.p_inad = min(self.cliente.inad * self.mtpl_inad *(1 + self.choque) , 0.70)
        self.prazo = int(np.random.uniform(low=1, high=10, size=None)) * 6 * (1 + chave_prazo[self.modalidade])
        self.juros = 0.01
        self.mtpl_rec = chave_mdld_rec[self.modalidade]
        self.parcela = npf.pmt(self.juros, self.prazo, self.valor)
        self.multa = 0
        self.pagamento = 0
        self.contrato = contrato
        self.atraso = 0
        self.mes = mes
        self.dia = dia

# %% [markdown]
# ### Gerar Operações por dia e agregar na base com o mês

# %%
def contrata(mes, ctr_dia, ref, choque):
    
    operacoes = []

    for d in range(1, 31):
        q = np.random.poisson(lam=ctr_dia, size=None)
        
        for i in range(q):
            operacoes.append(operacao(str(mes).zfill(3) + str(d).zfill(2)+(str(i)).zfill(6), ref, mes, d, choque))
            
    return(operacoes)

# %% [markdown]
# ### Atualização do mês
# #### e inclusão de novas contratações

# %%
def atualiza_mes(anterior, ctr_dia=50, choque = 0.0):
    #print(len(anterior))
    atual = []

    for i in range(len(anterior)):

        atual.append(anterior[i])

        dia = 30 - anterior[i].dia
        
        #ajustar atraso para somar 30 dias se menor que 30 dia se não + 30
        
        p_atraso = np.random.binomial(size = None, n = 1, p = min(anterior[i].p_inad, 0.99999))
        
        if anterior[i].atraso < 30:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * dia
        else:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * 30
            
        if temp_atraso == 0:
            p = min(anterior[i].p_inad * (1  + choque), 0.70)
        elif temp_atraso < 30:
            p = 0.20 + 0.20 * (temp_atraso - 0)/30
        elif temp_atraso < 60:
            p = 0.40 + 0.10 * (temp_atraso - 30)/30
        elif temp_atraso < 90:    
            p = 0.50 + 0.05 * (temp_atraso - 60)/30
        elif temp_atraso < 120:
            p = 0.75 * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 150:
            p = 0.80 * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 180:
            p = 0.85  * chave_mdld_rec[atual[i].modalidade]
        elif temp_atraso < 270:
            p = 0.90
        elif temp_atraso < 300:
            p = 0.95 
        elif temp_atraso < 330:
            p = 0.975 
        elif temp_atraso < 360:
            p = 0.995 
        else:
            p = 1.000

        atual[i].cliente.inad = anterior[i].cliente.inad * (p/anterior[i].p_inad)
        atual[i].p_inad = p
        atual[i].prazo = anterior[i].prazo - 1
        atual[i].ref = anterior[i].ref + 1
        
        atual[i].valor = max((anterior[i].valor) * (1 + anterior[i].juros) + ((anterior[i].parcela - atual[i].multa) * (1 - p_atraso)), 0)  
        
        #if atual[i].modalidade == 4 and anterior[i].atraso > 90 and p_atraso == 0:
        if anterior[i].atraso > chave_atraso_rec[atual[i].modalidade] and p_atraso == 0:
                    atual[i].pagamento = atual[i].valor
                    atual[i].valor = 0
                    atual[i].prazo = 0
        else:
            atual[i].pagamento = (-anterior[i].parcela + anterior[i].multa) * (1 - p_atraso)
            
        atual[i].atraso = temp_atraso

        atual[i].multa = - (anterior[i].parcela * p_atraso * (1 + anterior[i].juros)) + (anterior[i].multa * p_atraso)
        
        
    atual.extend(contrata(anterior[i].mes + 1, ctr_dia, anterior[i].ref, choque = choque))
    
    return(atual)

        ## Incluir probabilidade de inadimplência em 1 mês ok
        ## atualizar dias de atraso ok
        ## utilizar probabilidades de recuperação e inadimplência do System Dynamics ok
        
        
        ## atualizar mes de referencia ok
        ## atualizar prazo ok
        ## atualizar liquidação ok
        ## exportar cada nova tabela ok
        ## criar loop ok
        ## atualizar probabilidades na base de clientes ok

# %% [markdown]
# ## Bases geradas

# %%
nmes = 180
mes_choque = [84, 132]
ichoque = 0.05
ctr_dia = 100

m = []
f = []

now = datetime.datetime.now()
print ("Início do processamento base 0 :", now.strftime("%Y-%m-%d %H:%M:%S"))
    
base0 = contrata(0, ctr_dia, 0, choque = 0.0)
linhas = len(base0)

conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
cur = conn.cursor(cursor_factory = ext.DictCursor)

for n in range(linhas):
    log = []
    sql = "INSERT INTO jpcosta.operacoes2( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
    values = [base0[n].ref , base0[n].cliente.codigo, base0[n].cliente.porte, base0[n].contrato, base0[n].modalidade, base0[n].prazo, base0[n].valor, base0[n].mes, base0[n].dia, base0[n].p_inad, base0[n].cliente.inad, base0[n].atraso, base0[n].pagamento]
    cur.execute(sql, values)
    conn.commit()
    results = cur.fetchall()
cur.close()
conn.close()


now = datetime.datetime.now()

print ("Fim do processamento base 0    :", now.strftime("%Y-%m-%d %H:%M:%S"))

for i in range(nmes):
    
    if ((i >= mes_choque[0]) & (i <= mes_choque[1])):
        texto = 'choque de ' + str(ichoque)
        choque = ichoque
    else:
        texto = 'sem choque'
        choque = 0.0
        
    now = datetime.datetime.now()
    print ("Início do processamento base", str(i + 1), "(", texto, "):", now.strftime("%Y-%m-%d %H:%M:%S"))
    exec("base" + str(i+1) + " = atualiza_mes(" + "base" + str(i) + ", "+ str(ctr_dia) + ", choque = "+ str(choque) + ")",)
    exec("linhas = len(base" + str(i + 1) + ")")      

    conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
    cur = conn.cursor(cursor_factory = ext.DictCursor)
    exec("linhas = len(base" + str(i + 1) + ")")
    
    for n in range(linhas):
        exec("saldo = base" + str(i + 1) + "[n].valor")
        exec("dias = base" + str(i + 1) + "[n].atraso")
        exec("prazo = base" + str(i + 1) + "[n].prazo")
        if saldo < 1.0 and dias == 0 and prazo < 0:
            None
        else:
            sql = "INSERT INTO jpcosta.operacoes2( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
            exec("values = [base"+ str(i+1) + "[n].ref " + ", base"+ str(i+1) + "[n].cliente.codigo" + ", base"+ str(i+1) + "[n].cliente.porte" + ", base"+ str(i+1) + "[n].contrato" + ", base"+ str(i+1) + "[n].modalidade" +  ", base"+ str(i+1) + "[n].prazo" + ", base"+ str(i+1) + "[n].valor" + ", base"+ str(i+1) + "[n].mes" +
                 ", base"+ str(i+1) + "[n].dia" + ", base"+ str(i+1) + "[n].p_inad" + ", base"+ str(i+1) + "[n].cliente.inad" + ", base"+ str(i+1) + "[n].atraso" + ", base"+ str(i+1) + "[n].pagamento]", globals(), locals())
            cur.execute(sql, values)
            conn.commit()
            results = cur.fetchall()
            
            m.append(i)
            exec("f.append(" + "base" + str(i+1) +"[n].p_inad)")
            
    cur.close()
    conn.close()
                
    now = datetime.datetime.now()
    print ("Fim do processamento base", str(i + 1), "   :", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Início do processamento base 0 : 2021-12-23 01:12:22
# Fim do processamento base 0    : 2021-12-23 01:12:33
# Início do processamento base 1 ( sem choque ): 2021-12-23 01:12:33
# Fim do processamento base 1    : 2021-12-23 01:12:57
# Início do processamento base 2 ( sem choque ): 2021-12-23 01:12:57
# Fim do processamento base 2    : 2021-12-23 01:13:32
# Início do processamento base 3 ( sem choque ): 2021-12-23 01:13:32
# Fim do processamento base 3    : 2021-12-23 01:14:18
# Início do processamento base 4 ( sem choque ): 2021-12-23 01:14:18
# Fim do processamento base 4    : 2021-12-23 01:15:17
# Início do processamento base 5 ( sem choque ): 2021-12-23 01:15:17
# Fim do processamento base 5    : 2021-12-23 01:16:27
# Início do processamento base 6 ( sem choque ): 2021-12-23 01:16:27
# Fim do processamento base 6    : 2021-12-23 01:18:01
# Início do processamento base 7 ( sem choque ): 2021-12-23 01:18:01
# Fim do processamento base 7    : 2021-12-23 01:19:47
# Início do processamento base 8 ( sem choque ): 2021-12-23 01:19:47
# Fim do processamento base 8    : 2021-12-23 01:21:48
# Início do processamento base 9 ( sem choque ): 2021-12-23 01:21:48
# Fim do processamento base 9    : 2021-12-23 01:24:02
# Início do processamento base 10 ( sem choque ): 2021-12-23 01:24:02
# Fim do processamento base 10    : 2021-12-23 01:26:05
# Início do processamento base 11 ( sem choque ): 2021-12-23 01:26:05
# Fim do processamento base 11    : 2021-12-23 01:28:16
# Início do processamento base 12 ( sem choque ): 2021-12-23 01:28:16
# Fim do processamento base 12    : 2021-12-23 01:30:51
# Início do processamento base 13 ( sem choque ): 2021-12-23 01:30:51
# Fim do processamento base 13    : 2021-12-23 01:33:38
# Início do processamento base 14 ( sem choque ): 2021-12-23 01:33:38
# Fim do processamento base 14    : 2021-12-23 01:36:46
# Início do processamento base 15 ( sem choque ): 2021-12-23 01:36:46
# Fim do processamento base 15    : 2021-12-23 01:39:40
# Início do processamento base 16 ( sem choque ): 2021-12-23 01:39:40
# Fim do processamento base 16    : 2021-12-23 01:42:40
# Início do processamento base 17 ( sem choque ): 2021-12-23 01:42:40
# Fim do processamento base 17    : 2021-12-23 01:45:46
# Início do processamento base 18 ( sem choque ): 2021-12-23 01:45:46
# Fim do processamento base 18    : 2021-12-23 01:49:12
# Início do processamento base 19 ( sem choque ): 2021-12-23 01:49:12
# Fim do processamento base 19    : 2021-12-23 01:52:45
# Início do processamento base 20 ( sem choque ): 2021-12-23 01:52:45
# Fim do processamento base 20    : 2021-12-23 01:56:17
# Início do processamento base 21 ( sem choque ): 2021-12-23 01:56:17
# Fim do processamento base 21    : 2021-12-23 02:00:00
# Início do processamento base 22 ( sem choque ): 2021-12-23 02:00:00
# Fim do processamento base 22    : 2021-12-23 02:03:46
# Início do processamento base 23 ( sem choque ): 2021-12-23 02:03:46
# Fim do processamento base 23    : 2021-12-23 02:07:44
# Início do processamento base 24 ( sem choque ): 2021-12-23 02:07:44
# Fim do processamento base 24    : 2021-12-23 02:11:44
# Início do processamento base 25 ( sem choque ): 2021-12-23 02:11:44
# Fim do processamento base 25    : 2021-12-23 02:15:52
# Início do processamento base 26 ( sem choque ): 2021-12-23 02:15:52
# Fim do processamento base 26    : 2021-12-23 02:20:09
# Início do processamento base 27 ( sem choque ): 2021-12-23 02:20:09
# Fim do processamento base 27    : 2021-12-23 02:24:31
# Início do processamento base 28 ( sem choque ): 2021-12-23 02:24:31
# Fim do processamento base 28    : 2021-12-23 02:29:00
# Início do processamento base 29 ( sem choque ): 2021-12-23 02:29:00
# Fim do processamento base 29    : 2021-12-23 02:33:34
# Início do processamento base 30 ( sem choque ): 2021-12-23 02:33:34
# Fim do processamento base 30    : 2021-12-23 02:38:20
# Início do processamento base 31 ( sem choque ): 2021-12-23 02:38:20
# Fim do processamento base 31    : 2021-12-23 02:43:09
# Início do processamento base 32 ( sem choque ): 2021-12-23 02:43:09
# Fim do processamento base 32    : 2021-12-23 02:48:05
# Início do processamento base 33 ( sem choque ): 2021-12-23 02:48:05
# Fim do processamento base 33    : 2021-12-23 02:53:10
# Início do processamento base 34 ( sem choque ): 2021-12-23 02:53:10
# Fim do processamento base 34    : 2021-12-23 02:58:27
# Início do processamento base 35 ( sem choque ): 2021-12-23 02:58:27
# Fim do processamento base 35    : 2021-12-23 03:03:45
# Início do processamento base 36 ( sem choque ): 2021-12-23 03:03:45
# Fim do processamento base 36    : 2021-12-23 03:09:15
# Início do processamento base 37 ( sem choque ): 2021-12-23 03:09:15
# Fim do processamento base 37    : 2021-12-23 03:14:44
# Início do processamento base 38 ( sem choque ): 2021-12-23 03:14:44
# Fim do processamento base 38    : 2021-12-23 03:20:19
# Início do processamento base 39 ( sem choque ): 2021-12-23 03:20:19
# Fim do processamento base 39    : 2021-12-23 03:26:05
# Início do processamento base 40 ( sem choque ): 2021-12-23 03:26:05
# Fim do processamento base 40    : 2021-12-23 03:31:57
# Início do processamento base 41 ( sem choque ): 2021-12-23 03:31:57
# Fim do processamento base 41    : 2021-12-23 03:37:52
# Início do processamento base 42 ( sem choque ): 2021-12-23 03:37:52
# Fim do processamento base 42    : 2021-12-23 03:44:00
# Início do processamento base 43 ( sem choque ): 2021-12-23 03:44:00
# Fim do processamento base 43    : 2021-12-23 03:50:07
# Início do processamento base 44 ( sem choque ): 2021-12-23 03:50:07
# Fim do processamento base 44    : 2021-12-23 03:56:18
# Início do processamento base 45 ( sem choque ): 2021-12-23 03:56:18
# Fim do processamento base 45    : 2021-12-23 04:02:33
# Início do processamento base 46 ( sem choque ): 2021-12-23 04:02:33
# Fim do processamento base 46    : 2021-12-23 04:08:56
# Início do processamento base 47 ( sem choque ): 2021-12-23 04:08:56
# Fim do processamento base 47    : 2021-12-23 04:15:30
# Início do processamento base 48 ( sem choque ): 2021-12-23 04:15:30
# Fim do processamento base 48    : 2021-12-23 04:22:10
# Início do processamento base 49 ( sem choque ): 2021-12-23 04:22:10
# Fim do processamento base 49    : 2021-12-23 04:28:50
# Início do processamento base 50 ( sem choque ): 2021-12-23 04:28:50
# Fim do processamento base 50    : 2021-12-23 04:35:40
# Início do processamento base 51 ( sem choque ): 2021-12-23 04:35:40
# Fim do processamento base 51    : 2021-12-23 04:42:29
# Início do processamento base 52 ( sem choque ): 2021-12-23 04:42:29
# Fim do processamento base 52    : 2021-12-23 04:49:20
# Início do processamento base 53 ( sem choque ): 2021-12-23 04:49:20
# Fim do processamento base 53    : 2021-12-23 04:56:18
# Início do processamento base 54 ( sem choque ): 2021-12-23 04:56:18
# Fim do processamento base 54    : 2021-12-23 05:03:18
# Início do processamento base 55 ( sem choque ): 2021-12-23 05:03:18
# Fim do processamento base 55    : 2021-12-23 05:10:27
# Início do processamento base 56 ( sem choque ): 2021-12-23 05:10:27
# Fim do processamento base 56    : 2021-12-23 05:17:39
# Início do processamento base 57 ( sem choque ): 2021-12-23 05:17:39
# Fim do processamento base 57    : 2021-12-23 05:24:55
# Início do processamento base 58 ( sem choque ): 2021-12-23 05:24:55
# Fim do processamento base 58    : 2021-12-23 05:32:22
# Início do processamento base 59 ( sem choque ): 2021-12-23 05:32:22
# Fim do processamento base 59    : 2021-12-23 05:39:45
# Início do processamento base 60 ( sem choque ): 2021-12-23 05:39:45
# Fim do processamento base 60    : 2021-12-23 05:47:20
# Início do processamento base 61 ( sem choque ): 2021-12-23 05:47:20
# Fim do processamento base 61    : 2021-12-23 05:54:50
# Início do processamento base 62 ( sem choque ): 2021-12-23 05:54:50
# Fim do processamento base 62    : 2021-12-23 06:02:24
# Início do processamento base 63 ( sem choque ): 2021-12-23 06:02:24
# Fim do processamento base 63    : 2021-12-23 06:10:06
# Início do processamento base 64 ( sem choque ): 2021-12-23 06:10:06
# Fim do processamento base 64    : 2021-12-23 06:17:52
# Início do processamento base 65 ( sem choque ): 2021-12-23 06:17:52
# Fim do processamento base 65    : 2021-12-23 06:25:47
# Início do processamento base 66 ( sem choque ): 2021-12-23 06:25:47
# Fim do processamento base 66    : 2021-12-23 06:33:41
# Início do processamento base 67 ( sem choque ): 2021-12-23 06:33:41
# Fim do processamento base 67    : 2021-12-23 06:41:45
# Início do processamento base 68 ( sem choque ): 2021-12-23 06:41:45
# Fim do processamento base 68    : 2021-12-23 06:49:45
# Início do processamento base 69 ( sem choque ): 2021-12-23 06:49:45
# Fim do processamento base 69    : 2021-12-23 06:57:51
# Início do processamento base 70 ( sem choque ): 2021-12-23 06:57:51
# Fim do processamento base 70    : 2021-12-23 07:06:03
# Início do processamento base 71 ( sem choque ): 2021-12-23 07:06:03
# Fim do processamento base 71    : 2021-12-23 07:14:25
# Início do processamento base 72 ( sem choque ): 2021-12-23 07:14:25
# Fim do processamento base 72    : 2021-12-23 07:22:45
# Início do processamento base 73 ( sem choque ): 2021-12-23 07:22:45
# Fim do processamento base 73    : 2021-12-23 07:31:11
# Início do processamento base 74 ( sem choque ): 2021-12-23 07:31:11
# Fim do processamento base 74    : 2021-12-23 07:39:40
# Início do processamento base 75 ( sem choque ): 2021-12-23 07:39:40
# Fim do processamento base 75    : 2021-12-23 07:48:13
# Início do processamento base 76 ( sem choque ): 2021-12-23 07:48:13
# Fim do processamento base 76    : 2021-12-23 07:56:53
# Início do processamento base 77 ( sem choque ): 2021-12-23 07:56:53
# Fim do processamento base 77    : 2021-12-23 08:05:39
# Início do processamento base 78 ( sem choque ): 2021-12-23 08:05:39
# Fim do processamento base 78    : 2021-12-23 08:14:28
# Início do processamento base 79 ( sem choque ): 2021-12-23 08:14:28
# Fim do processamento base 79    : 2021-12-23 08:23:20
# Início do processamento base 80 ( sem choque ): 2021-12-23 08:23:20
# Fim do processamento base 80    : 2021-12-23 08:32:16
# Início do processamento base 81 ( sem choque ): 2021-12-23 08:32:16
# Fim do processamento base 81    : 2021-12-23 08:41:15
# Início do processamento base 82 ( sem choque ): 2021-12-23 08:41:15
# Fim do processamento base 82    : 2021-12-23 08:50:22
# Início do processamento base 83 ( sem choque ): 2021-12-23 08:50:22
# Fim do processamento base 83    : 2021-12-23 08:59:41
# Início do processamento base 84 ( sem choque ): 2021-12-23 08:59:41
# Fim do processamento base 84    : 2021-12-23 09:08:55
# Início do processamento base 85 ( choque de 0.05 ): 2021-12-23 09:08:55
# Fim do processamento base 85    : 2021-12-23 09:18:39
# Início do processamento base 86 ( choque de 0.05 ): 2021-12-23 09:18:39
# Fim do processamento base 86    : 2021-12-23 09:28:19
# Início do processamento base 87 ( choque de 0.05 ): 2021-12-23 09:28:19
# Fim do processamento base 87    : 2021-12-23 09:38:01
# Início do processamento base 88 ( choque de 0.05 ): 2021-12-23 09:38:01
# Fim do processamento base 88    : 2021-12-23 09:47:50
# Início do processamento base 89 ( choque de 0.05 ): 2021-12-23 09:47:50
# Fim do processamento base 89    : 2021-12-23 09:57:43
# Início do processamento base 90 ( choque de 0.05 ): 2021-12-23 09:57:43
# Fim do processamento base 90    : 2021-12-23 10:07:42
# Início do processamento base 91 ( choque de 0.05 ): 2021-12-23 10:07:42
# Fim do processamento base 91    : 2021-12-23 10:17:48
# Início do processamento base 92 ( choque de 0.05 ): 2021-12-23 10:17:48
# Fim do processamento base 92    : 2021-12-23 10:27:55
# Início do processamento base 93 ( choque de 0.05 ): 2021-12-23 10:27:55
# Fim do processamento base 93    : 2021-12-23 10:38:06
# Início do processamento base 94 ( choque de 0.05 ): 2021-12-23 10:38:06
# Fim do processamento base 94    : 2021-12-23 10:48:27
# Início do processamento base 95 ( choque de 0.05 ): 2021-12-23 10:48:27
# Fim do processamento base 95    : 2021-12-23 10:59:20
# Início do processamento base 96 ( choque de 0.05 ): 2021-12-23 10:59:20
# Fim do processamento base 96    : 2021-12-23 11:09:51
# Início do processamento base 97 ( choque de 0.05 ): 2021-12-23 11:09:51
# Fim do processamento base 97    : 2021-12-23 11:20:25
# Início do processamento base 98 ( choque de 0.05 ): 2021-12-23 11:20:25
# Fim do processamento base 98    : 2021-12-23 11:31:05
# Início do processamento base 99 ( choque de 0.05 ): 2021-12-23 11:31:05
# Fim do processamento base 99    : 2021-12-23 11:41:48
# Início do processamento base 100 ( choque de 0.05 ): 2021-12-23 11:41:48
# Fim do processamento base 100    : 2021-12-23 11:52:36
# Início do processamento base 101 ( choque de 0.05 ): 2021-12-23 11:52:36
# Fim do processamento base 101    : 2021-12-23 12:03:31
# Início do processamento base 102 ( choque de 0.05 ): 2021-12-23 12:03:31

# %%
cur.close()
conn.close()

# %% [raw]
# conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=jpcosta password=12345678")
# cur = conn.cursor(cursor_factory = ext.DictCursor)
#
# sql = "DELETE FROM jpcosta.operacoes WHERE ref > -1;"
# cur.execute(sql)
#
# cur.execute(sql)
# conn.commit()
# cur.close()
# conn.close()
