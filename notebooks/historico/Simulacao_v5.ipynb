# %%
import numpy as np
import random
import pandas as pd
import numpy_financial as npf

import os
import psycopg2
import psycopg2.extras as ext
import datetime

# %%
''''
chave_prob = {1 : 0.015,
             2:  0.010,
             3:  0.008,
             4:  0.006,
             5:  0.002,
             6:  0.0000}
'''''
chave_prob = {1 : 1.50,
              2:  1.00,
              3:  0.90,
              4:  0.80,
              5:  0.60,
              6:  0.40}   
    
chave_valr = {1 : 1.00,
             2:  1.50,
             3:  2.00,
             4:  3.00,
             5:  3.50,
             6:  4.00}

# %%
#[0.419, 0.156, 0.167, 0.146, 0.072, 0.041]
#[1/6, 1/6, 1/6, 1/6, 1/6, 1/6]

class cliente:
    def __init__(self, codigo):
        self.codigo = codigo
 #       self.inad = max(0.02 + np.random.normal(0., 0.005),0.003)
        self.porte = int(np.where(np.random.multinomial(1, [0.419, 0.156, 0.167, 0.146, 0.072, 0.041], size=1) == 1)[1][0] + 1)
        self.inad = max(0.02 + np.random.normal(0., 0.005),0.0003) * chave_prob[self.porte]
        self.mtlp = chave_valr[self.porte]

# %% [markdown]
# ## Simula base de clientes

# %%
clientes = []

for i in range(50000):
    clientes.append(cliente(str(i).zfill(7)))

# %%
chave_mdld_rec = {1 : 1.000,
                  2:  0.700,
                  3:  0.400,
                  4:  0.100}

chave_atraso_rec = {1: 120,
                   2: 120,
                   3: 90,
                   4: 90}

chave_mdld_valor = {1 : 4,
                    2:  2,
                    3:  5,
                    4:  10}

chave_prazo =      {1 : 0,
                    2:  0,
                    3:  0,
                    4:  5}

chave_prt_inad =      {1 : 4.50,
                       2:  3.00,
                       3:  2.00,
                       4:  1.00}

# %%
import matplotlib.pyplot as plt 

plt.hist(np.random.lognormal(8., 0.5, size=1000))
# Out:
# (array([228., 430., 202.,  95.,  23.,  12.,   8.,   1.,   0.,   1.]),
#  array([  603.0404663 ,  2079.14248397,  3555.24450163,  5031.3465193 ,
#          6507.44853697,  7983.55055464,  9459.6525723 , 10935.75458997,
#         12411.85660764, 13887.95862531, 15364.06064298]),
#  <BarContainer object of 10 artists>)

# %%
#[0.147, 0.779, 0.050, 0.024]
#[1/4, 1/4, 1/4, 1/4]

class operacao:
    def __init__(self, contrato, ref,  mes, dia):
        self.ref = ref
        self.cliente = random.sample(clientes, 1)[0]
        self.modalidade = int(np.where(np.random.multinomial(1, [0.137, 0.757, 0.070, 0.036], size=1) == 1)[1][0] + 1)
        self.valor = (np.random.lognormal(8., 0.5, size=None)) * chave_mdld_valor[self.modalidade] * self.cliente.mtlp
        self.mtpl_inad = chave_prt_inad[self.modalidade]
        self.p_inad = min(self.cliente.inad * self.mtpl_inad, 0.8)
        self.prazo = int(np.random.uniform(low=1, high=10, size=None)) * 6 * (1 + chave_prazo[self.modalidade])
        self.juros = 0.01
        self.mtpl_rec = chave_mdld_rec[self.modalidade]
        self.parcela = npf.pmt(self.juros, self.prazo, self.valor)
        self.multa = 0
        self.pagamento = 0
        self.contrato = contrato
        self.atraso = 0
        self.mes = mes
        self.dia = dia

# %% [markdown]
# ### Gerar Operações por dia e agregar na base com o mês

# %%
def contrata(mes, ctr_dia, ref):
    
    operacoes = []

    for d in range(1, 31):
        q = np.random.poisson(lam=ctr_dia, size=None)
        
        for i in range(q):
            operacoes.append(operacao(str(mes).zfill(3) + str(d).zfill(2)+(str(i)).zfill(6), ref, mes, d))
            
    return(operacoes)

# %% [markdown]
# ### Atualização do mês
# #### e inclusão de novas contratações

# %%
def atualiza_mes(anterior, ctr_dia=50):
    #print(len(anterior))
    atual = []

    for i in range(len(anterior)):

        atual.append(anterior[i])

        dia = 30 - anterior[i].dia
        
        #ajustar atraso para somar 30 dias se menor que 30 dia se não + 30
        
        p_atraso = np.random.binomial(size = None, n = 1, p = min(anterior[i].p_inad, 0.99999))
        if anterior[i].atraso < 30:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * dia
        else:
            temp_atraso = p_atraso * anterior[i].atraso + p_atraso * 30
            
        if anterior[i].atraso == 0:
            p = anterior[i].p_inad
        elif anterior[i].atraso < 30:
            p = 0.10 + 0.40 * (temp_atraso - 0)/30
        elif anterior[i].atraso < 60:
            p = 0.55 + 0.10 * (temp_atraso - 30)/30
        elif anterior[i].atraso < 90:    
            p = 0.70 + 0.05 * (temp_atraso - 60)/30
        elif anterior[i].atraso < 120:
            p = 0.76 * anterior[i].mtpl_rec
        elif anterior[i].atraso < 150:
            p = 0.78 * anterior[i].mtpl_rec
        elif anterior[i].atraso < 180:
            p = 0.80  * anterior[i].mtpl_rec
        elif anterior[i].atraso < 270:
            p = 0.85 
        elif anterior[i].atraso < 300:
            p = 0.90 
        elif anterior[i].atraso < 330:
            p = 0.95 
        elif anterior[i].atraso < 360:
            p = 0.999 
        else:
            p = 0.99999

        atual[i].cliente.inad = anterior[i].cliente.inad * (p/anterior[i].p_inad)
        atual[i].p_inad = p
        atual[i].prazo = anterior[i].prazo - 1
        atual[i].ref = anterior[i].ref + 1
        
        atual[i].valor = max((anterior[i].valor) * (1 + anterior[i].juros) + ((anterior[i].parcela - atual[i].multa) * (1 - p_atraso)), 0)  
        
        #if atual[i].modalidade == 4 and anterior[i].atraso > 90 and p_atraso == 0:
        if anterior[i].atraso > chave_atraso_rec[atual[i].modalidade] and p_atraso == 0:
                    atual[i].pagamento = atual[i].valor
                    atual[i].valor = 0
                    atual[i].prazo = 0
        else:
            atual[i].pagamento = (-anterior[i].parcela + anterior[i].multa) * (1 - p_atraso)
            
        atual[i].atraso = temp_atraso

        atual[i].multa = - (anterior[i].parcela * p_atraso * (1 + anterior[i].juros)) + (anterior[i].multa * p_atraso)
        
        
    atual.extend(contrata(anterior[i].mes + 1, ctr_dia, anterior[i].ref))
    
    return(atual)

        ## Incluir probabilidade de inadimplência em 1 mês ok
        ## atualizar dias de atraso ok
        ## utilizar probabilidades de recuperação e inadimplência do System Dynamics ok
        
        
        ## atualizar mes de referencia ok
        ## atualizar prazo ok
        ## atualizar liquidação ok
        ## exportar cada nova tabela ok
        ## criar loop ok
        ## atualizar probabilidades na base de clientes ok

# %% [markdown]
# ## Bases geradas

# %%
nmes = 200
ctr_dia = 10
    
now = datetime.datetime.now()
print ("Início do processamento base 0 :", now.strftime("%Y-%m-%d %H:%M:%S"))
    
base0 = contrata(0, ctr_dia, 0)
linhas = len(base0)

conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
cur = conn.cursor(cursor_factory = ext.DictCursor)

for n in range(linhas):
    log = []
    sql = "INSERT INTO jpcosta.operacoes( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
    values = [base0[n].ref , base0[n].cliente.codigo, base0[n].cliente.porte, base0[n].contrato, base0[n].modalidade, base0[n].prazo, base0[n].valor, base0[n].mes, base0[n].dia, base0[n].p_inad, base0[n].cliente.inad, base0[n].atraso, base0[n].pagamento]
    cur.execute(sql, values)
    conn.commit()
    results = cur.fetchall()
cur.close()
conn.close()


now = datetime.datetime.now()

print ("Fim do processamento base 0    :", now.strftime("%Y-%m-%d %H:%M:%S"))

for i in range(nmes):
    now = datetime.datetime.now()
    print ("Início do processamento base", str(i + 1), ":", now.strftime("%Y-%m-%d %H:%M:%S"))
    exec("base" + str(i+1) + " = atualiza_mes(" + "base" + str(i) + ", "+ str(ctr_dia) + ")",)
    exec("linhas = len(base" + str(i + 1) + ")")      

    conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=postgres password=12345678")
    cur = conn.cursor(cursor_factory = ext.DictCursor)
    exec("linhas = len(base" + str(i + 1) + ")")
    
    for n in range(linhas):
        exec("saldo = base" + str(i + 1) + "[n].valor")
        exec("dias = base" + str(i + 1) + "[n].atraso")
        exec("prazo = base" + str(i + 1) + "[n].prazo")
        if saldo < 1.0 and dias == 0 and prazo < 0:
            None
        else:
            sql = "INSERT INTO jpcosta.operacoes( ref, cliente, porte, contrato, modalidade, prazo, valor, mes, dia, prob_opr, prob_cli, atraso, pgto ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) RETURNING *;"
            exec("values = [base"+ str(i+1) + "[n].ref " + ", base"+ str(i+1) + "[n].cliente.codigo" + ", base"+ str(i+1) + "[n].cliente.porte" + ", base"+ str(i+1) + "[n].contrato" + ", base"+ str(i+1) + "[n].modalidade" +  ", base"+ str(i+1) + "[n].prazo" + ", base"+ str(i+1) + "[n].valor" + ", base"+ str(i+1) + "[n].mes" +
                 ", base"+ str(i+1) + "[n].dia" + ", base"+ str(i+1) + "[n].p_inad" + ", base"+ str(i+1) + "[n].cliente.inad" + ", base"+ str(i+1) + "[n].atraso" + ", base"+ str(i+1) + "[n].pagamento]", globals(), locals())
            cur.execute(sql, values)
            conn.commit()
            results = cur.fetchall()
    cur.close()
    conn.close()
                
    now = datetime.datetime.now()
    print ("Fim do processamento base", str(i + 1), "   :", now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Início do processamento base 0 : 2021-12-14 00:42:58
# Fim do processamento base 0    : 2021-12-14 00:42:59
# Início do processamento base 1 : 2021-12-14 00:42:59
# Fim do processamento base 1    : 2021-12-14 00:43:01
# Início do processamento base 2 : 2021-12-14 00:43:01
# Fim do processamento base 2    : 2021-12-14 00:43:04
# Início do processamento base 3 : 2021-12-14 00:43:04
# Fim do processamento base 3    : 2021-12-14 00:43:08
# Início do processamento base 4 : 2021-12-14 00:43:08
# Fim do processamento base 4    : 2021-12-14 00:43:13
# Início do processamento base 5 : 2021-12-14 00:43:13
# Fim do processamento base 5    : 2021-12-14 00:43:20
# Início do processamento base 6 : 2021-12-14 00:43:20
# Fim do processamento base 6    : 2021-12-14 00:43:27
# Início do processamento base 7 : 2021-12-14 00:43:27
# Fim do processamento base 7    : 2021-12-14 00:43:35
# Início do processamento base 8 : 2021-12-14 00:43:35
# Fim do processamento base 8    : 2021-12-14 00:43:44
# Início do processamento base 9 : 2021-12-14 00:43:44
# Fim do processamento base 9    : 2021-12-14 00:43:54
# Início do processamento base 10 : 2021-12-14 00:43:54
# Fim do processamento base 10    : 2021-12-14 00:44:05
# Início do processamento base 11 : 2021-12-14 00:44:05
# Fim do processamento base 11    : 2021-12-14 00:44:17
# Início do processamento base 12 : 2021-12-14 00:44:17
# Fim do processamento base 12    : 2021-12-14 00:44:30
# Início do processamento base 13 : 2021-12-14 00:44:30
# Fim do processamento base 13    : 2021-12-14 00:44:44
# Início do processamento base 14 : 2021-12-14 00:44:44
# Fim do processamento base 14    : 2021-12-14 00:44:58
# Início do processamento base 15 : 2021-12-14 00:44:58
# Fim do processamento base 15    : 2021-12-14 00:45:14
# Início do processamento base 16 : 2021-12-14 00:45:14
# Fim do processamento base 16    : 2021-12-14 00:45:30
# Início do processamento base 17 : 2021-12-14 00:45:30
# Fim do processamento base 17    : 2021-12-14 00:45:48
# Início do processamento base 18 : 2021-12-14 00:45:48
# Fim do processamento base 18    : 2021-12-14 00:46:06
# Início do processamento base 19 : 2021-12-14 00:46:06
# Fim do processamento base 19    : 2021-12-14 00:46:24
# Início do processamento base 20 : 2021-12-14 00:46:24
# Fim do processamento base 20    : 2021-12-14 00:46:44
# Início do processamento base 21 : 2021-12-14 00:46:44
# Fim do processamento base 21    : 2021-12-14 00:47:04
# Início do processamento base 22 : 2021-12-14 00:47:04
# Fim do processamento base 22    : 2021-12-14 00:47:25
# Início do processamento base 23 : 2021-12-14 00:47:25
# Fim do processamento base 23    : 2021-12-14 00:47:46
# Início do processamento base 24 : 2021-12-14 00:47:46
# Fim do processamento base 24    : 2021-12-14 00:48:10
# Início do processamento base 25 : 2021-12-14 00:48:10
# Fim do processamento base 25    : 2021-12-14 00:48:35
# Início do processamento base 26 : 2021-12-14 00:48:35
# Fim do processamento base 26    : 2021-12-14 00:48:59
# Início do processamento base 27 : 2021-12-14 00:48:59
# Fim do processamento base 27    : 2021-12-14 00:49:25
# Início do processamento base 28 : 2021-12-14 00:49:25
# Fim do processamento base 28    : 2021-12-14 00:49:51
# Início do processamento base 29 : 2021-12-14 00:49:51
# Fim do processamento base 29    : 2021-12-14 00:50:17
# Início do processamento base 30 : 2021-12-14 00:50:17
# Fim do processamento base 30    : 2021-12-14 00:50:43
# Início do processamento base 31 : 2021-12-14 00:50:43
# Fim do processamento base 31    : 2021-12-14 00:51:11
# Início do processamento base 32 : 2021-12-14 00:51:11
# Fim do processamento base 32    : 2021-12-14 00:51:41
# Início do processamento base 33 : 2021-12-14 00:51:41
# Fim do processamento base 33    : 2021-12-14 00:52:09
# Início do processamento base 34 : 2021-12-14 00:52:09
# Fim do processamento base 34    : 2021-12-14 00:52:39
# Início do processamento base 35 : 2021-12-14 00:52:39
# Fim do processamento base 35    : 2021-12-14 00:53:08
# Início do processamento base 36 : 2021-12-14 00:53:08
# Fim do processamento base 36    : 2021-12-14 00:53:38
# Início do processamento base 37 : 2021-12-14 00:53:38
# Fim do processamento base 37    : 2021-12-14 00:54:08
# Início do processamento base 38 : 2021-12-14 00:54:08
# Fim do processamento base 38    : 2021-12-14 00:54:39
# Início do processamento base 39 : 2021-12-14 00:54:39
# Fim do processamento base 39    : 2021-12-14 00:55:11
# Início do processamento base 40 : 2021-12-14 00:55:11
# Fim do processamento base 40    : 2021-12-14 00:55:44
# Início do processamento base 41 : 2021-12-14 00:55:44
# Fim do processamento base 41    : 2021-12-14 00:56:17
# Início do processamento base 42 : 2021-12-14 00:56:17
# Fim do processamento base 42    : 2021-12-14 00:56:49
# Início do processamento base 43 : 2021-12-14 00:56:49
# Fim do processamento base 43    : 2021-12-14 00:57:23
# Início do processamento base 44 : 2021-12-14 00:57:23
# Fim do processamento base 44    : 2021-12-14 00:57:58
# Início do processamento base 45 : 2021-12-14 00:57:58
# Fim do processamento base 45    : 2021-12-14 00:58:32
# Início do processamento base 46 : 2021-12-14 00:58:32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f76d5fe6745d> in <module>
#      47                  ", base"+ str(i+1) + "[n].dia" + ", base"+ str(i+1) + "[n].p_inad" + ", base"+ str(i+1) + "[n].cliente.inad" + ", base"+ str(i+1) + "[n].atraso" + ", base"+ str(i+1) + "[n].pagamento]", globals(), locals())
#      48             cur.execute(sql, values)
# ---> 49             conn.commit()
#      50             results = cur.fetchall()
#      51     cur.close()
#
# KeyboardInterrupt:

# %%
cur.close()
conn.close()

# %% [raw]
# conn = psycopg2.connect("host=localhost port=5432 dbname=Simulacred user=jpcosta password=12345678")
# cur = conn.cursor(cursor_factory = ext.DictCursor)
#
# sql = "DELETE FROM jpcosta.operacoes WHERE ref > -1;"
# cur.execute(sql)
#
# cur.execute(sql)
# conn.commit()
# cur.close()
# conn.close()
